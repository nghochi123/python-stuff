# %% [markdown]
# <a href="https://colab.research.google.com/github/nghochi123/python-stuff/blob/master/Exploratory_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ad44223f-72c5-47f0-af28-d2bc75864a5d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ad44223f-72c5-47f0-af28-d2bc75864a5d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kc_house_data.csv to kc_house_data.csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['kc_house_data.csv']))

# %%
df.describe()
# Out:
#                  id         price  ...  sqft_living15     sqft_lot15
# count  2.159700e+04  2.159700e+04  ...   21597.000000   21597.000000
# mean   4.580474e+09  5.402966e+05  ...    1986.620318   12758.283512
# std    2.876736e+09  3.673681e+05  ...     685.230472   27274.441950
# min    1.000102e+06  7.800000e+04  ...     399.000000     651.000000
# 25%    2.123049e+09  3.220000e+05  ...    1490.000000    5100.000000
# 50%    3.904930e+09  4.500000e+05  ...    1840.000000    7620.000000
# 75%    7.308900e+09  6.450000e+05  ...    2360.000000   10083.000000
# max    9.900000e+09  7.700000e+06  ...    6210.000000  871200.000000
#
# [8 rows x 20 columns]

# %%
plt.figure(figsize=(12,6))
sns.distplot(df['price'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.countplot(df['bedrooms'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='price', y='sqft_living', data=df)

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='bedrooms', y='price', data=df)

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='price', y='long', data=df)

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='price', y='lat', data=df)

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='long', y='lat', data=df, hue='price')

# %%
df.sort_values('price', ascending=False).head(30)
# Out:
#                id        date      price  ...     long  sqft_living15  sqft_lot15
# 7245   6762700020  10/13/2014  7700000.0  ... -122.323           3940        8800
# 3910   9808700762   6/11/2014  7060000.0  ... -122.214           3930       25449
# 9245   9208900037   9/19/2014  6890000.0  ... -122.240           4540       42730
# 4407   2470100110    8/4/2014  5570000.0  ... -122.233           3560       24345
# 1446   8907500070   4/13/2015  5350000.0  ... -122.220           4600       21750
# 1313   7558700030   4/13/2015  5300000.0  ... -122.210           4320       24619
# 1162   1247600105  10/20/2014  5110000.0  ... -122.211           3430       26788
# 8085   1924059029   6/17/2014  4670000.0  ... -122.210           3270       10454
# 2624   7738500731   8/15/2014  4500000.0  ... -122.280           3030       23408
# 8629   3835500195   6/18/2014  4490000.0  ... -122.219           3720       14592
# ...

# %%
df_trunc = df.sort_values('price', ascending=False).iloc[216:]

# %%
df_trunc.head()
# Out:
#                id        date      price  ...     long  sqft_living15  sqft_lot15
# 6329    824059321    6/2/2014  1970000.0  ... -122.204           2960       10347
# 12271  1923000260  10/15/2014  1960000.0  ... -122.215           3700       14486
# 9166   3124059023   2/13/2015  1960000.0  ... -122.220           3730       16560
# 12565  2806300065   4/22/2015  1960000.0  ... -122.157           3900       35237
# 1150   4055701200   4/21/2015  1960000.0  ... -122.259           2630       13868
#
# [5 rows x 21 columns]

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='long', y='lat', data=df_trunc, hue='price', edgecolor=None, alpha=0.2, palette='RdYlGn')

# %%
sns.boxplot(x='waterfront', y='price', data=df)

# %%
df = df.drop('id', axis=1)

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
df['year'] = df['date'].apply(lambda date: date.year)

# %%
df['month'] = df['date'].apply(lambda date: date.month)

# %%
df.head()
# Out:
#         date     price  bedrooms  ...  sqft_lot15  year  month
# 0 2014-10-13  221900.0         3  ...        5650  2014     10
# 1 2014-12-09  538000.0         3  ...        7639  2014     12
# 2 2015-02-25  180000.0         2  ...        8062  2015      2
# 3 2014-12-09  604000.0         4  ...        5000  2014     12
# 4 2015-02-18  510000.0         3  ...        7503  2015      2
#
# [5 rows x 22 columns]

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='month', y='price', data=df)

# %%
df.groupby('month').mean()['price']
# Out:
# month
# 1     525963.251534
# 2     508520.051323
# 3     544057.683200
# 4     562215.615074
# 5     550849.746893
# 6     557534.318182
# 7     544892.161013
# 8     536655.212481
# 9     529723.517787
# 10    539439.447228
# 11    522359.903478
# 12    524799.902041
# Name: price, dtype: float64

# %%
df = df.drop('date', axis=1)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  ...  sqft_lot15  year  month
# 0  221900.0         3       1.00  ...        5650  2014     10
# 1  538000.0         3       2.25  ...        7639  2014     12
# 2  180000.0         2       1.00  ...        8062  2015      2
# 3  604000.0         4       3.00  ...        5000  2014     12
# 4  510000.0         3       2.00  ...        7503  2015      2
#
# [5 rows x 21 columns]

# %%
df = df.drop('zipcode', axis=1)
